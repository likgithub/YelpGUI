# %%
'''

given an output .csv of all franchises in a given state, return the one with the largest spread
-> Spread here is defined as the maximum area bounded by lat/long points of the outermost locations
   of a given franchise's cluster
   
   LEFTMOST, RIGHTMOST = min(longitude), max(longitude)
   TOPMOST, BOTTOMMOST = max(latitude), min(longitude)

df = (business_id, name, latitude, longitude) for each business in STATE where is_franchise > 0

'''

import pandas as pd

df_t = pd.DataFrame(pd.read_csv(r'business/business_location.csv', low_memory=False))
df_tt = df_t[df_t.is_franchise == 1]
df_ttt = df_tt[['business_id', 'name', 'state', 'latitude', 'longitude']] 
input_state = 'AB'
df = df_ttt[df_ttt.state == input_state][['business_id', 'name', 'latitude', 'longitude']]

# %%
#pwd = '...' # set the project working directory here
#df = pd.DataFrame(pd.read_csv(f'{pwd}/temp_table_out.csv'), low_memory=False)
print("This is what we pull from pSQL:")
df
# Out:
# This is what we pull from pSQL:
#                    business_id                       name   latitude  \
# 331     aoI2O7lr0zTTwwib3qdEFA                  Dollarama  51.126021
# 398     _CVSEnwbg5oRD5DKMmrrNg             North Taphouse  51.164105
# 627     Wxt77slJbuwQ3LDbfrBkzQ      Ricky's All Day Grill  50.978672
# 671     UkBy7Epd2q6YXZhYas8iEA                        A&W  50.989084
# 736     YTMYCiBb_-sykowc05d3ug                Snow Palace  51.125894
# ...                        ...                        ...        ...
# 208995  a91uOoAgbgVkX3Sx7hkEtA            A Perfect Pizza  51.266098
# 209062  M4YaHnHP6BzCwB_NrNlzyw                Tim Hortons  51.048247
# 209121  _xITq0q08REnLLfgaHMEog                        KFC  50.969186
# 209219  vsTNApse_Wsw61Od9YOZqQ  Pho An Vietnamese Cuisine  50.977744
# 209387  KdGtDThLduB8Vf-z-qKEFA                       Aldo  50.997571
#
#          longitude
# 331    -114.071359
# 398    -113.962796
# 627    -114.041571
# 671    -113.957469
# 736    -114.210850
# ...            ...
# 208995 -113.993379
# 209062 -114.065870
# 209121 -114.070789
# 209219 -114.071475
# 209387 -114.073369
#
# [2179 rows x 4 columns]

# %%
# sort by name
df.sort_values(by='name', inplace=True)
df

current_name = df.name.iloc[0]
# Out:
# True

# %%
max_spread = ['null', 0] # this will be [name, spread]
name_list = list(set([n for n in df.name]))
name_list
# Out:
# ['Babylon Qithara',
#  'Village Ice Cream',
#  'The Next Level',
#  'TD Canada Trust',
#  'Extreme Pita',
#  'Kal Tire',
#  'Misai Japanese',
#  'Women In Need Society',
#  "Vern's Pizza",
#  'EB Games',
#  "St John's Music",
#  'Bento Sushi',
#  'Home Depot',
#  "Victoria's Secret",
#  'CaseMogul',
#  'Fitz Flooring',
#  'San Remo Ristorante',
#  'BMW Gallery',
#  'Safeway',
#  'Cobs Bread',
#  'Bongs & Such',
#  "Caesar's Steak House",
#  'Milestones',
#  'Cameo & Cufflinks',
#  'Koya Japan',
#  'Pet Valu',
#  'Autotemp Air & Sound',
#  'Little Caesars Pizza',
#  'Little Caesars',
#  'Planet Organic Market',
#  'Kinjo Sushi',
#  'Minute Muffler & Brake',
#  "Mark's",
#  'Cookies By George',
#  'Sophies Pizza',
#  'Crystal Glass Canada',
#  'Fitness Depot',
#  'Spice 7',
#  'Cedars Deli',
#  'Ginger Beef Express',
#  'The One Sushi',
#  'The Laundry Store',
#  'Chocolaterie Bernard Callebaut',
#  'Deville Coffee',
#  'Hi-Ball Restaurant',
#  'Booster Juice',
#  'Edo Japan',
#  'Thai Bistro',
#  'Shell Canada Products',
#  "Rip's Pub & Eatery",
#  'Fresh-adilla, Fresh Tortilla',
#  'Chapters',
#  "Hudsons Canada's Pub",
#  'Marble Slab Creamery',
#  'Pho Hoan Pasteur',
#  'Sport Chek',
#  'Phamtastic Nails & Spa',
#  'Visions Electronics',
#  'Waffles & Chix',
#  'Lucky Supermarket',
#  'M & M Meat Shops',
#  'Las Canarias',
#  'LensCrafters',
#  'Hakim Optical',
#  'The Canadian Brewhouse',
#  "Marcello's Market & Deli",
#  'Banzai Sushi & Teriyaki House',
#  'Denim & Smith Barbershops',
#  'Petro-Canada',
#  'Safeway Food & Drug',
#  'Rona Home & Garden',
#  'Waves Coffee House',
#  'Sally Beauty Supply',
#  'Bo Bebe',
#  'EggsOasis',
#  "Hudson's Bay",
#  'Medicentres',
#  'Royal Auto Sales',
#  'Carstar',
#  'Tail Blazers',
#  'Chatime',
#  'Advance Hair & Spa',
#  "Humpty's Family Restaurants",
#  'Good Earth Cafes',
#  'Cococo Chocolaterie Bernard Callebaut',
#  'Umi Sushi Express',
#  'Urban Rice',
#  'Guitarworks',
#  "Leopold's Tavern",
#  "Phil's Restaurants",
#  'Rbc Royal Bank',
#  'Fusion Sushi',
#  'Mainstreet Equity Corporation',
#  'Los Compadres',
#  "Smitty's Restaurant",
#  'Dragon Gate Restaurant',
#  'The Brow Studio',
#  'Co-op',
#  'Maharajah East Indian Restaurant',
#  'Bull & Finch',
#  "Christopher's Fine Dry Cleaning",
#  'Buffalo Wild Wings',
#  "East Side Mario's",
#  'Home Outfitters',
#  "Papa John's Pizza",
#  'The Bay',
#  'Check Mate Shoes',
#  'Kona Poke',
#  'Po-ke',
#  'Pet Planet',
#  "Wendy's",
#  'Rocky Mountain Soap Company',
#  'My Favorite Ice Cream Shoppe',
#  'Hula',
#  'MVP Modern Barbers',
#  'Ripe Tomato Pizza',
#  'Globefish Sushi & Izakaya',
#  'Twisted Goods',
#  'Avis Car & Truck Rental',
#  'Bon Ton Meat Market',
#  'Saje Natural Wellness',
#  'Angles Hair & Aesthetics',
#  'Browns Shoes',
#  'Budget Cleaners',
#  'Rusty Cage',
#  'Ski Cellar Snowboard',
#  "Applebee's Grill + Bar",
#  'Swimco',
#  'Human Kanvas',
#  'Wok Box',
#  'Once Upon A Child',
#  'Noodlebox',
#  'Pizza Cottage',
#  'Tiki Ming',
#  'Mucho Burrito',
#  'London Barbers',
#  'Stitch It Clothing Alterations',
#  "Chachi's Sandwich Bar",
#  'A Little More Interesting',
#  'PetSmart',
#  'Dairy Queen Grill & Chill',
#  'La Prep',
#  'Popeyes Louisiana Kitchen',
#  'You & I Coffee',
#  'Earls Kitchen + Bar',
#  'Enlighten Laser & Skin Care Clinic',
#  'Lube City',
#  'Subs N More',
#  'Blush Lane Organic Market',
#  'Beer Revolution',
#  'Sakana Grill',
#  'Famous Wok',
#  'Chatters Hair Salon',
#  "Arby's Restaurant",
#  'Sunterra Market',
#  'Shell Canada',
#  'Touch of India',
#  'Holy Smoke BBQ',
#  'Murale',
#  'First Calgary Financial',
#  'Pita Basket',
#  "Gillette's Fabricare",
#  'Long & McQuade',
#  'Atlantic Trap & Gill Pub',
#  "Kim's Emerald Nail Salon",
#  'Canada Post',
#  'Merle Norman Cosmetics & Day Spa',
#  'Mobile Depot',
#  'EFW Radiology',
#  'Chicago Chophouse',
#  "Ric's Lounge & Grill",
#  'Bulk Barn',
#  'Oak & Vine',
#  'The Rocket',
#  'Auto Value Auto Parts',
#  'Lush Cosmetics',
#  'Paris Jewellers',
#  'Quesada Burritos & Tacos',
#  'Pita Stop',
#  'Koryo Korean BBQ',
#  "Chasin' Tails",
#  'Value Village',
#  'deVille Luxury Coffee & Pastries',
#  'Bliss & Co. Cupcakes & Desserts',
#  'Pearle Vision',
#  'Athabasca University',
#  'Enterprise Rent-A-Car',
#  'Pizza Hut',
#  'Green Chili',
#  'Chatters Hair Beauty Salon',
#  'Silver City Restaurant',
#  'Tire Pirates',
#  'Panago Pizza',
#  'Midas',
#  'The Silk Road Spice Merchant',
#  'Saneal Camera Supplies',
#  'Schanks Sports Grill',
#  'Shell',
#  'Regal Beagle Pub',
#  "Tony Roma's",
#  'Jerusalem Shawarma',
#  'Crepe Delicious',
#  'Sears',
#  'Eats of Asia',
#  'Wonton King',
#  'Buttermilk Fine Waffles',
#  'Wind Mobile',
#  "Ricky's All Day Grill",
#  'Crystal Glass',
#  'Pita Grill',
#  'Big Bucket Car Wash',
#  'Teavana',
#  'iPhix',
#  'Knibbe Automotive Repair',
#  'Woodridge Ford Lincoln',
#  'Willow Park Wines & Spirits',
#  'Brewsters Brewing Company & Restaurant',
#  'Unimarket',
#  '7-Eleven',
#  "Fair's Fair Books",
#  'Fish Creek Nissan',
#  'Good Earth Coffeehouse',
#  'Shiraz Persian Cuisine',
#  'Pizza 3000',
#  "Jysk Linen 'n Furniture",
#  'StorageMart',
#  'Barbecues Galore',
#  'Hertz Rent A Car',
#  'Fatburger',
#  'Gummi Boutique',
#  'CIBC',
#  'Panda Express',
#  "Ric's Grill",
#  'Burger 320',
#  'Pizza 73',
#  'YMCA Calgary',
#  "Domino's Pizza",
#  'Karma Salon',
#  'Starlight Nails & Spa',
#  'Calgary Laboratory Services',
#  'Rexall',
#  'The Blind Monk',
#  'Q & P Fashion Cleaners',
#  'Fit4Less',
#  'The Chopped Leaf',
#  'Walmart',
#  "Nick's Steak House & Pizza",
#  'Your Dollar World',
#  'Ama',
#  'Princess Auto',
#  'Trail Appliances',
#  'Coach',
#  'Amaranth Whole Foods Market',
#  'The Source Snowboards & Skateboards',
#  'Laptop Depot',
#  '4th Street Pizza',
#  'Real Canadian Wholesale Club',
#  'Mr Sub',
#  'Made By Marcus',
#  'Good Taste of Britain',
#  'Virgin Mobile',
#  'Racks Unlimited',
#  'CRAFT Beer Market',
#  'Peacock Boutique Consignment',
#  'GoodLife Fitness',
#  'Monogram Coffee',
#  'Lakeview Bakery',
#  'Purdys Chocolatier',
#  'Michaels',
#  'Calgary BMW',
#  'Kickaxe Guitars',
#  'Pie Junkie',
#  'Mr Schnapps Restaurant & Bar',
#  'Boyd Autobody & Glass',
#  'Adobo Experience',
#  'Regal Nails',
#  'Starbucks',
#  'Save On Foods',
#  'The Second Cup',
#  'Saigon Y2K Vietnamese Restaurant',
#  'Rise Bakery',
#  "Fionn MacCool's Irish Pub",
#  'Discount Car & Truck Rentals',
#  'Minit Lube',
#  'Community Natural Foods',
#  'Burger King Restaurant',
#  'Accentric Salon & Spa',
#  'Dynamic Vacuums',
#  'Apex Massage Therapy',
#  'My Donair',
#  'OEB Breakfast',
#  'Future Shop',
#  'Cowtown Beef Shack',
#  'Ok Tire & Auto Service',
#  'Clearwash',
#  "Harvey's",
#  'Real Canadian Superstore',
#  'Ginger Beef Peking House',
#  "Mac's",
#  'Tu Tierra',
#  'Dairy Queen',
#  'Great Clips',
#  'OPA! of Greece',
#  'Thai Express',
#  'The Block',
#  "Bianca Amor's Liquidation Supercentre",
#  'Lifemark',
#  'Memory Express',
#  'The Locked Room',
#  'Calgary Shawarma',
#  'Venetian Nails Spa',
#  'Sidewalk Citizen Bakery',
#  'Kung Fu Restaurant',
#  'Old Navy',
#  'Budget Car & Truck Rental',
#  'Zyn',
#  'Broken Plate Kitchen & Bar',
#  'Dollarama',
#  'Burger Inn',
#  'Running Room Canada',
#  "The Bro'Kin Yolk",
#  'Frilly Lilly',
#  'London Drugs',
#  'Oriental Phoenix Restaurant',
#  'Fabutan - Hush Lash Studio',
#  'Wicked Chili',
#  'Tim Hortons',
#  'Solo Liquor',
#  'Phil & Sebastian Coffee Roasters',
#  'Vietnam Palace Grill & Noodle House',
#  'Banana Republic',
#  'Pho An Vietnamese Cuisine',
#  'The Licensing Company',
#  'Bath and Body Works',
#  'Fitness Plus',
#  'Atmosphere',
#  'Beyond Beautiful',
#  'Toys R Us',
#  'Western Pride Car Wash',
#  'Amato Gelato Cafe',
#  'H&R Block',
#  'Freshii',
#  'Moores Clothing for Men',
#  'Zellers',
#  'South St. Burger',
#  "Original Joe's",
#  'Barcelos Flame Grilled Chicken',
#  'Red Lobster',
#  'Blaskin & Lane Tire Centres',
#  'Mastermind Toys',
#  'DAVIDsTEA',
#  'Cash Canada',
#  "Jack's Classic Nails & Spa",
#  'Passport Canada',
#  'Professionail',
#  'Vine Styles',
#  'Panther Sports Medicine & Rehabilitation Centres',
#  'The Desert Pita & Grill',
#  'Cactus Club Cafe',
#  'Speedy Glass',
#  'Rona',
#  'Salt & Pepper Mexican Restaurant',
#  'Fuji Yama Japanese Restaurant',
#  "Tom's House of Pizza",
#  'Fritou Chicken',
#  'Boardwalk Fresh Burgers and Fries',
#  'Boston Pizza',
#  'Simple Simon Pies',
#  'Angles Hair and Aesthetics',
#  'Santé Spa',
#  'Homesense',
#  'Canadian Tire',
#  'Fabutan',
#  'Fabricland',
#  'Western Pizza',
#  'Browz Eyeware',
#  'Revolve Furnishings',
#  'Thai Tai',
#  'Pho So 1',
#  "Uncle Moe's Donairs & Falafels",
#  'Winners',
#  'Tuk Tuk Thai',
#  'RedBloom Salon',
#  'Lot 102',
#  'Analog Coffee',
#  'Smashburger',
#  'Monki Breakfastclub & Bistro',
#  'Sobeys',
#  "Menchie's",
#  "Jameson's Irish Pub",
#  "Woody's Taphouse",
#  'Indigo',
#  'Villa Madina',
#  'Gong Cha',
#  'Bed Bath and Beyond',
#  'Costa Vida',
#  'Kensington Art Supply',
#  'Made Foods',
#  'Ultracuts Professional Haircare Centres',
#  'Chili Club Thai House',
#  'Nam Vietnamese Kitchen',
#  'CalAlta Auto Glass',
#  'La-Z-Boy Furniture Galleries',
#  'Jiffy Lube',
#  'Global Pet Foods',
#  'Meineke Car Care Centre',
#  'Purolator Courier',
#  'T&T Supermarket',
#  'Fresh Kitchen',
#  'Aritzia',
#  'Supercuts',
#  'First Choice Haircutters',
#  'IRIS',
#  "Chachi's",
#  'Suzette Brittany Bistro',
#  "Lowe's",
#  "Tim Horton's",
#  'Budget Blinds',
#  'Aldo',
#  'Van Son Vietnamese Cuisine',
#  'Sirens',
#  'Sushi Ichiban Japanese Restaurant',
#  'Via Cibo',
#  'Bellissima',
#  'Hedkandi Salon',
#  'Garbage Good Guys',
#  'Top Nails',
#  'Bmo Bank of Montreal',
#  'The Cheesecake Cafe',
#  'Jugo Juice',
#  'The Shoe Company',
#  "Shillelagh's Pub",
#  'Tai Pan',
#  'Color Me Mine',
#  'Milestones Restaurants',
#  'Crowfoot Wine & Spirits',
#  'KFC',
#  'ReNue',
#  'Moon Korean BBQ',
#  'Koryo Korean Barbeque',
#  'Contemporary Coachworks',
#  'Cora',
#  'Shark Club Sports Bar & Grill',
#  'Pacific Hut Restaurant',
#  'Good Earth Cafe',
#  'Five Guys',
#  'State & Main Kitchen & Bar',
#  'Rio Pizza',
#  'Royal Liquor Merchants',
#  'Edible Arrangements',
#  'Staples',
#  'Battery World',
#  'Canadian Pizza Unlimited',
#  'Town Shoes',
#  'Marina Dosa & Tandoori Grill',
#  'Harry Rosen',
#  'Oasis Medical Centre',
#  'Perfect Home',
#  'Sephora',
#  'Stampede Corral',
#  'Cool Vape',
#  'Beaners Fun Cuts For Kids',
#  'Mr. Lube',
#  "Timothy's World Coffee",
#  'Hennessey Salon + Spa',
#  'BraTopia',
#  'Purr',
#  'Swiss Chalet Rotisserie & Grill',
#  'Shoppers Drug Mart',
#  'Fergus & Bix',
#  'Subway',
#  'Kings Glass',
#  'Chennai Spices',
#  "Carl's Jr",
#  "Original Joe's Restaurant & Bar",
#  "Black's Photography",
#  'Banzai Restaurant',
#  'Chicago Deep Dish Pizza',
#  'The Modern Body Massage Spa',
#  'Fountain Tire',
#  'U-Haul Neighborhood Dealer',
#  'The UPS Store',
#  'Shawarma Barlow',
#  'Chicken on the Way',
#  'Taco Del Mar',
#  'Crave Cookies & Cupcakes',
#  'The Source',
#  'Cultures',
#  'Atomic',
#  'Taco Time',
#  'Pho Huong Viet Noodle House',
#  'MathPro Learning Centre',
#  'Bubbles Car Wash',
#  'Tutti Frutti',
#  "Chili's Texas Grill",
#  "Tommy Gun's Original Barbershop",
#  'Quiznos',
#  'Diva Salon Spa',
#  'La Viena',
#  'Blame Betty',
#  'Bow Tie Pizza',
#  'Verona Pizza',
#  'Solo Liquor Store',
#  'Saigon Maxim',
#  'North Taphouse',
#  'Taco Bell of Canada',
#  'Frocks Modern Bridesmaids',
#  'Shaw Communications',
#  'Pier 1',
#  'Premier Spa Boutique',
#  'A Perfect Pizza',
#  'Paws Pet Food & Accessories',
#  'Chop Steakhouse & Bar',
#  'The Brick',
#  'Eggsmart',
#  'Costco Wholesale',
#  'Phoenix Grill',
#  'Carrington Lighting',
#  'Yogen Fruz',
#  'Redwater Rustic Grille',
#  'The Old Spaghetti Factory',
#  'Springbank Cheese Company',
#  'Tropical Delight Noodle House',
#  "Smoker's Corner",
#  'Nawab Restaurant',
#  'XS Cargo',
#  'Diner Deluxe',
#  'Famoso Neapolitan Pizzeria',
#  'Yume Sushi',
#  'Tirecraft Calgary',
#  'Second Cup',
#  'Jusu Bar',
#  'Olive Chicken',
#  'Barre Body Studio',
#  'The Home Depot',
#  'Anytime Fitness',
#  'Jelly Modern Doughnuts',
#  "Montana's BBQ & Bar",
#  'Target',
#  'Rosso Coffee Roasters',
#  'SoftMoc',
#  'A&W',
#  'Snow Palace',
#  'Magic Nails',
#  'Dirtbelly',
#  'Hooters',
#  'Apple Store',
#  "Lammle's Western Wear & Tack",
#  'American Apparel',
#  'Basha Foods',
#  "Lorenzo's Pizzeria",
#  'Ajisai Japanese Cuisine',
#  'Sleep Country',
#  'The Great Canadian Bagel',
#  'TommyKplay',
#  'Tower Cleaners',
#  'Glory of India',
#  'Structube',
#  'Kinjo Sushi & Grill',
#  'Turn It Up Records & Hi-Fi',
#  "Joey's Seafood Restaurants",
#  'Urban Barn',
#  'Shawarma Palace',
#  "Moxie's Grill & Bar",
#  'Bowling Depot',
#  'Melrose Cafe & Bar',
#  'Little Burgundy',
#  'Highlander Wine & Spirits',
#  'Best Buy',
#  'Petland',
#  'Chianti Cafe & Restaurant',
#  'Raj Palace',
#  "Rocky's Burger Bus",
#  'Party City',
#  "McDonald's",
#  "Denny's"]

# %%
# LEFTMOST, RIGHTMOST = min(longitude), max(longitude)
# TOPMOST, BOTTOMMOST = max(latitude), min(longitude)

for business_name in name_list:
    df_l = df[df.name == business_name]
    for row in df_l.itertuples():

        LEFTMOST = 0
        RIGHTMOST = 0
        TOPMOST = 0
        BOTTOMMOST = 0

        lat = row.latitude
        long = row.longitude

        if long < LEFTMOST: LEFTMOST = lat
        elif long > RIGHTMOST: RIGHTMOST = long
        if lat > TOPMOST: TOPMOST = lat
        elif lat < BOTTOMMOST: BOTTOMMOST = lat

        horizontal = abs(RIGHTMOST - LEFTMOST)
        vertical = abs(TOPMOST - BOTTOMMOST)

        spread = horizontal * vertical

        if spread > max_spread[1]:
            max_spread = [row.name, spread]

# %%
max_spread
# Out:
# ["Smoker's Corner", 2631.0923991894597]

# %%
ret_business_name = max_spread[0]
ret_business_name
# Out:
# "Smoker's Corner"
